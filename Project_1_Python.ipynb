# %% [markdown]
# # Rock-Paper-Scissors Game
#
# Welcome to the Rock-Paper-Scissors game! You can play against the computer by selecting one of the buttons below (Rock, Paper, or Scissors). The computer will randomly pick one as well, and the result will be displayed right here. Have fun!

# %%
"""

import random
import ipywidgets as widgets
from IPython.display import display, clear_output

# List of choices for the game
choices = ["rock", "paper", "scissors"]

# Function to determine the winner
def determine_winner(player_choice, computer_choice):
    if player_choice == computer_choice:
        return "It's a tie!"
    elif (player_choice == "rock" and computer_choice == "scissors") or \
         (player_choice == "scissors" and computer_choice == "paper") or \
         (player_choice == "paper" and computer_choice == "rock"):
        return "You win!"
    else:
        return "Computer wins!"

# Function to play the game
def play_game(player_choice):
    computer_choice = random.choice(choices)
    result = determine_winner(player_choice, computer_choice)
    clear_output()
    print(f"You chose: {player_choice}")
    print(f"Computer chose: {computer_choice}")
    print(result)

# Create buttons for user choices
rock_button = widgets.Button(description="Rock")
paper_button = widgets.Button(description="Paper")
scissors_button = widgets.Button(description="Scissors")

# Set up actions for each button
rock_button.on_click(lambda x: play_game("rock"))
paper_button.on_click(lambda x: play_game("paper"))
scissors_button.on_click(lambda x: play_game("scissors"))

# Display the buttons
display(rock_button, paper_button, scissors_button)


"""
# Out:
# You chose: rock
# Computer chose: paper
# Computer wins!

# %%
"""

import random
import ipywidgets as widgets
from IPython.display import display, clear_output

# Image URLs for the buttons (replace with actual URLs or local file paths)
rock_image_url = "https://example.com/rock.png"
paper_image_url = "https://example.com/paper.png"
scissors_image_url = "https://example.com/scissors.png"

# Choices for the game
choices = ["rock", "paper", "scissors"]

# Function to determine the winner
def determine_winner(player_choice, computer_choice):
    if player_choice == computer_choice:
        return "It's a tie!"
    elif (player_choice == "rock" and computer_choice == "scissors") or \
         (player_choice == "scissors" and computer_choice == "paper") or \
         (player_choice == "paper" and computer_choice == "rock"):
        return "You win!"
    else:
        return "Computer wins!"

# Function to play the game
def play_game(player_choice):
    computer_choice = random.choice(choices)
    result = determine_winner(player_choice, computer_choice)
    clear_output()
    display(f"You chose: {player_choice.capitalize()}")
    display(f"Computer chose: {computer_choice.capitalize()}")
    display(result)

# Create buttons with images
rock_button = widgets.Button(
    description="Rock",
    style={'button_color': '#e0e0e0'},
    layout=widgets.Layout(width='150px', height='150px'),
    icon="fa-hand-rock",  # Optionally add an icon
    button_style='',
    tooltip='Rock',
)
paper_button = widgets.Button(
    description="Paper",
    style={'button_color': '#e0e0e0'},
    layout=widgets.Layout(width='150px', height='150px'),
    icon="fa-hand-paper",
    button_style='',
    tooltip='Paper',
)
scissors_button = widgets.Button(
    description="Scissors",
    style={'button_color': '#e0e0e0'},
    layout=widgets.Layout(width='150px', height='150px'),
    icon="fa-hand-scissors",
    button_style='',
    tooltip='Scissors',
)

# Set up button click events
rock_button.on_click(lambda x: play_game("rock"))
paper_button.on_click(lambda x: play_game("paper"))
scissors_button.on_click(lambda x: play_game("scissors"))

# Display the buttons
buttons_box = widgets.HBox([rock_button, paper_button, scissors_button])
display(buttons_box)
"""
# Out:
# 'You chose: Scissors'
# 'Computer chose: Rock'
# 'Computer wins!'

# %%
"""

import random
import ipywidgets as widgets
from IPython.display import display, clear_output

# Choices for the game
choices = ["rock", "paper", "scissors"]

# Create an Output widget to display the result message
output = widgets.Output()

# Function to determine the winner and return the result and color
def determine_winner(player_choice, computer_choice):
    if player_choice == computer_choice:
        return "It's a tie!", 'orange'
    elif (player_choice == "rock" and computer_choice == "scissors") or \
         (player_choice == "scissors" and computer_choice == "paper") or \
         (player_choice == "paper" and computer_choice == "rock"):
        return "You win!", 'green'
    else:
        return "Computer wins!", 'red'

# Function to play the game and display the result
def play_game(player_choice):
    computer_choice = random.choice(choices)
    result_message, color = determine_winner(player_choice, computer_choice)

    # Clear previous output and display the new result
    with output:
        clear_output()
        print(f"You chose: {player_choice.capitalize()}")
        print(f"Computer chose: {computer_choice.capitalize()}")
        display(widgets.HTML(f"<h2 style='color:{color}'>{result_message}</h2>"))

# Create buttons with images or text
rock_button = widgets.Button(description='Rock', layout=widgets.Layout(width='150px', height='150px'))
paper_button = widgets.Button(description='Paper', layout=widgets.Layout(width='150px', height='150px'))
scissors_button = widgets.Button(description='Scissors', layout=widgets.Layout(width='150px', height='150px'))

# Set up button click events
rock_button.on_click(lambda x: play_game("rock"))
paper_button.on_click(lambda x: play_game("paper"))
scissors_button.on_click(lambda x: play_game("scissors"))

# Display the buttons and the result output
buttons_box = widgets.HBox([rock_button, paper_button, scissors_button])
display(buttons_box, output)
"""
# Out:
# HBox(children=(Button(description='Rock', layout=Layout(height='150px', width='150px'), style=ButtonStyle()), …
# Output()

# %%
import random
import ipywidgets as widgets
from IPython.display import display, clear_output

# Image URLs for buttons (relative URLs from your GitHub repository)
rock_image_url = "images/rock.png"
paper_image_url = "images/paper.png"
scissors_image_url = "images/scissors.png"

# Choices for the game
choices = ["rock", "paper", "scissors"]

# Create an Output widget to display the result message
output = widgets.Output()

# Function to determine the winner and return the result and color
def determine_winner(player_choice, computer_choice):
    if player_choice == computer_choice:
        return "It's a tie!", 'orange'
    elif (player_choice == "rock" and computer_choice == "scissors") or \
         (player_choice == "scissors" and computer_choice == "paper") or \
         (player_choice == "paper" and computer_choice == "rock"):
        return "You win!", 'green'
    else:
        return "Computer wins!", 'red'

# Function to play the game and display the result
def play_game(player_choice):
    computer_choice = random.choice(choices)
    result_message, color = determine_winner(player_choice, computer_choice)

    # Clear previous output and display the new result
    with output:
        clear_output()
        print(f"You chose: {player_choice.capitalize()}")
        print(f"Computer chose: {computer_choice.capitalize()}")
        display(widgets.HTML(f"<h2 style='color:{color}'>{result_message}</h2>"))

# Create buttons with images instead of text
rock_button = widgets.Button(
    description=f"<img src='{rock_image_url}' style='width:100px;height:100px;'>",
    layout=widgets.Layout(width='150px', height='150px'),
    tooltip='Rock'
)
paper_button = widgets.Button(
    description=f"<img src='{paper_image_url}' style='width:100px;height:100px;'>",
    layout=widgets.Layout(width='150px', height='150px'),
    tooltip='Paper'
)
scissors_button = widgets.Button(
    description=f"<img src='{scissors_image_url}' style='width:100px;height:100px;'>",
    layout=widgets.Layout(width='150px', height='150px'),
    tooltip='Scissors'
)

# Set up button click events
rock_button.on_click(lambda x: play_game("rock"))
paper_button.on_click(lambda x: play_game("paper"))
scissors_button.on_click(lambda x: play_game("scissors"))

# Display the buttons and the result output
buttons_box = widgets.HBox([rock_button, paper_button, scissors_button])
display(buttons_box, output)
# Out:
# HBox(children=(Button(description="<img src='images/rock.png' style='width:100px;height:100px;'>", layout=Layo…
# Output()
